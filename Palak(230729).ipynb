# %%
import numpy as np
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt

# %%
apple = yf.download("AAPL","2018-01-01","2025-06-28")
apple.info()
apple
# Out:
# /tmp/ipython-input-3-1902389105.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   apple = yf.download("AAPL","2018-01-01","2025-06-28")
# [*********************100%***********************]  1 of 1 completed
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1882 entries, 2018-01-02 to 2025-06-27
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   (Close, AAPL)   1882 non-null   float64
#  1   (High, AAPL)    1882 non-null   float64
#  2   (Low, AAPL)     1882 non-null   float64
#  3   (Open, AAPL)    1882 non-null   float64
#  4   (Volume, AAPL)  1882 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 88.2 KB
# Price            Close        High         Low        Open     Volume
# Ticker            AAPL        AAPL        AAPL        AAPL       AAPL
# Date
# 2018-01-02   40.426823   40.436212   39.722768   39.933986  102223600
# ...

# %%
stocks = ["TCS.NS", "HDFCBANK.NS", "RELIANCE.NS", "ICICIBANK.NS","INFY.NS"]


data = yf.download(stocks, start="2021-01-01", end="2025-06-27", auto_adjust=True)
# Out:
# [*********************100%***********************]  5 of 5 completed

# %%
data
# Out:
# Price             Close                                                      \
# Ticker      HDFCBANK.NS ICICIBANK.NS      INFY.NS  RELIANCE.NS       TCS.NS
# Date
# 2021-01-01  1353.131714   514.128113  1133.026489   914.128418  2707.164062
# 2021-01-04  1344.538330   518.221680  1158.015991   915.669189  2809.967773
# 2021-01-05  1354.698242   523.630981  1163.005005   904.285706  2859.474365
# 2021-01-06  1348.858643   532.841370  1152.487793   880.437866  2821.108398
# 2021-01-07  1344.775757   527.383362  1134.554565   879.012085  2803.820557
# ...                 ...          ...          ...          ...          ...
# 2025-06-20  1943.321289  1427.099976  1622.900024  1466.199951  3435.699951
# 2025-06-23  1927.198730  1420.099976  1584.000000  1456.800049  3393.600098
# 2025-06-24  1939.562744  1424.099976  1581.599976  1450.800049  3390.399902
# 2025-06-25  1958.652710  1425.800049  1614.900024  1467.300049  3444.800049
# ...

# %%
close = data["Close"]
close
# Out:
# Ticker      HDFCBANK.NS  ICICIBANK.NS      INFY.NS  RELIANCE.NS       TCS.NS
# Date
# 2021-01-01  1353.131714    514.128113  1133.026489   914.128418  2707.164062
# 2021-01-04  1344.538330    518.221680  1158.015991   915.669189  2809.967773
# 2021-01-05  1354.698242    523.630981  1163.005005   904.285706  2859.474365
# 2021-01-06  1348.858643    532.841370  1152.487793   880.437866  2821.108398
# 2021-01-07  1344.775757    527.383362  1134.554565   879.012085  2803.820557
# ...                 ...           ...          ...          ...          ...
# 2025-06-20  1943.321289   1427.099976  1622.900024  1466.199951  3435.699951
# 2025-06-23  1927.198730   1420.099976  1584.000000  1456.800049  3393.600098
# 2025-06-24  1939.562744   1424.099976  1581.599976  1450.800049  3390.399902
# 2025-06-25  1958.652710   1425.800049  1614.900024  1467.300049  3444.800049
# 2025-06-26  1999.800049   1439.099976  1616.000000  1495.300049  3441.800049
#
# [1108 rows x 5 columns]

# %%
close = close[stocks]
close
# Out:
# Ticker           TCS.NS  HDFCBANK.NS  RELIANCE.NS  ICICIBANK.NS      INFY.NS
# Date
# 2021-01-01  2707.164062  1353.131714   914.128418    514.128113  1133.026489
# 2021-01-04  2809.967773  1344.538330   915.669189    518.221680  1158.015991
# 2021-01-05  2859.474365  1354.698242   904.285706    523.630981  1163.005005
# 2021-01-06  2821.108398  1348.858643   880.437866    532.841370  1152.487793
# 2021-01-07  2803.820557  1344.775757   879.012085    527.383362  1134.554565
# ...                 ...          ...          ...           ...          ...
# 2025-06-20  3435.699951  1943.321289  1466.199951   1427.099976  1622.900024
# 2025-06-23  3393.600098  1927.198730  1456.800049   1420.099976  1584.000000
# 2025-06-24  3390.399902  1939.562744  1450.800049   1424.099976  1581.599976
# 2025-06-25  3444.800049  1958.652710  1467.300049   1425.800049  1614.900024
# 2025-06-26  3441.800049  1999.800049  1495.300049   1439.099976  1616.000000
#
# [1108 rows x 5 columns]

# %%
returns = close.pct_change(fill_method=None).dropna(how="all")
returns
# Out:
# Ticker        TCS.NS  HDFCBANK.NS  RELIANCE.NS  ICICIBANK.NS   INFY.NS
# Date
# 2021-01-04  0.037975    -0.006351     0.001686      0.007962  0.022056
# 2021-01-05  0.017618     0.007556    -0.012432      0.010438  0.004308
# 2021-01-06 -0.013417    -0.004311    -0.026372      0.017589 -0.009043
# 2021-01-07 -0.006128    -0.003027    -0.001619     -0.010243 -0.015560
# 2021-01-08  0.029049     0.010874     0.011799      0.001756  0.039576
# ...              ...          ...          ...           ...       ...
# 2025-06-20  0.003417     0.015191     0.022954      0.011195  0.002781
# 2025-06-23 -0.012254    -0.008296    -0.006411     -0.004905 -0.023969
# 2025-06-24 -0.000943     0.006416    -0.004119      0.002817 -0.001515
# 2025-06-25  0.016045     0.009842     0.011373      0.001194  0.021055
# 2025-06-26 -0.000871     0.021008     0.019083      0.009328  0.000681
#
# [1107 rows x 5 columns]

# %%
expectation= returns.mean(axis=0)
expectation
# Out:
# Ticker
# TCS.NS          0.000305
# HDFCBANK.NS     0.000450
# RELIANCE.NS     0.000553
# ICICIBANK.NS    0.001033
# INFY.NS         0.000439
# dtype: float64

# %%
covariance = returns.cov()*252
covariance
# Out:
# Ticker          TCS.NS  HDFCBANK.NS  RELIANCE.NS  ICICIBANK.NS   INFY.NS
# Ticker
# TCS.NS        0.044472     0.010891     0.014658      0.010986  0.035961
# HDFCBANK.NS   0.010891     0.048852     0.018978      0.026957  0.014321
# RELIANCE.NS   0.014658     0.018978     0.054755      0.020532  0.016296
# ICICIBANK.NS  0.010986     0.026957     0.020532      0.052324  0.015349
# INFY.NS       0.035961     0.014321     0.016296      0.015349  0.059301

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(covariance, annot=True, cmap='coolwarm', fmt=".4f")
plt.title('Covariance Matrix of Stock Returns')
plt.show()

# %%
try:
    inverse_covariance = np.linalg.inv(covariance)
    print("\nInverse Covariance Matrix:")
    print(inverse_covariance)

    plt.figure(figsize=(10, 8))
    sns.heatmap(inverse_covariance, annot=True, cmap='coolwarm', fmt=".4f")
    plt.title('Inverse Covariance Matrix of Stock Returns')
    plt.show()

except np.linalg.LinAlgError:
    print("Error: The covariance matrix is singular and cannot be inverted.")
# Out:
# Inverse Covariance Matrix:
# [[ 45.05485421  -0.98551784  -4.07828598   0.28594316 -26.0369294 ]
#  [ -0.98551784  30.27299935  -4.77420128 -12.91213329  -2.05930356]
#  [ -4.07828598  -4.77420128  23.48632782  -5.48729907  -1.40767918]
#  [  0.28594316 -12.91213329  -5.48729907  28.73240207  -2.98392334]
#  [-26.0369294   -2.05930356  -1.40767918  -2.98392334  34.30857277]]

# %%
matrix1 = np.ones(5)
matrix1
# Out:
# array([1., 1., 1., 1., 1.])

# %%
matrix2 = np.dot(matrix1, np.dot(inverse_covariance, matrix1.T))
matrix2
# Out:
# np.float64(40.97649664478833)

# %%
optimal_weight= np.dot(inverse_covariance, matrix1)/matrix2
optimal_weight
# Out:
# array([0.34751785, 0.23286138, 0.188861  , 0.18632607, 0.0444337 ])

# %%
portfolio_volatility = np.sqrt(np.dot(optimal_weight.T, np.dot(covariance, optimal_weight)))
print(f"Portfolio Volatility: {portfolio_volatility*100:.4f}")
# Out:
# Portfolio Volatility: 15.6219

# %% [markdown]
# Plotting the Markowitz efficient Frontier

# %%
def generate_random_weights(num_stocks, num_portfolios):

  all_weights = []
  for _ in range(num_portfolios):
    weights = np.random.random(num_stocks)
    weights /= np.sum(weights)
    all_weights.append(weights)
  return np.array(all_weights)

num_stocks = len(stocks)
num_portfolios = 10000
random_weights = generate_random_weights(num_stocks, num_portfolios)

# You can print or inspect the first few generated weight vectors
print("First 5 random weight vectors:")
print(random_weights[:5])
# Out:
# First 5 random weight vectors:
# [[0.18774754 0.43454649 0.25268534 0.01872932 0.1062913 ]
#  [0.37021048 0.11233922 0.10970111 0.05796112 0.34978808]
#  [0.31173742 0.12252367 0.30543398 0.11832294 0.14198199]
#  [0.10783482 0.00796812 0.00849951 0.28686848 0.58882906]
#  [0.26983583 0.36020202 0.13422891 0.0737133  0.16201993]]

# %%
variance_matrix= np.dot(random_weights, np.dot(covariance, random_weights.T))
variance_matrix
# Out:
# array([[0.02671766, 0.02357791, 0.02432355, ..., 0.02444069, 0.02534267,
#         0.02252753],
#        [0.02357791, 0.03076184, 0.02615344, ..., 0.02580554, 0.02755204,
#         0.02578824],
#        [0.02432355, 0.02615344, 0.0258219 , ..., 0.02368019, 0.02510212,
#         0.02519019],
#        ...,
#        [0.02444069, 0.02580554, 0.02368019, ..., 0.02691432, 0.02585481,
#         0.02413377],
#        [0.02534267, 0.02755204, 0.02510212, ..., 0.02585481, 0.02697585,
#         0.02399298],
#        [0.02252753, 0.02578824, 0.02519019, ..., 0.02413377, 0.02399298,
#         0.02636007]])

# %%
portfolio_returns = np.dot(random_weights, expectation)
portfolio_volatility = np.sqrt(np.diag(variance_matrix))

plt.figure(figsize=(12, 8))
plt.scatter(portfolio_volatility, portfolio_returns, c=portfolio_returns, cmap='viridis', marker='o')
plt.title('Markowitz Efficient Frontier with Random Portfolios')
plt.xlabel('Portfolio Volatility (Standard Deviation)')
plt.ylabel('Portfolio Expected Return')
plt.colorbar(label='Expected Return')
plt.grid(True)
plt.show()

# %%
optimal_portfolio_return = np.dot(optimal_weight, expectation)
optimal_portfolio_volatility = np.sqrt(np.dot(optimal_weight.T, np.dot(covariance, optimal_weight)))


plt.figure(figsize=(12, 8))
plt.scatter(portfolio_volatility, portfolio_returns, c=portfolio_returns, cmap='viridis', marker='o', label='Random Portfolios')
plt.scatter(optimal_portfolio_volatility, optimal_portfolio_return, color='red', marker='*', s=200, label='Optimal Portfolio') # Highlight the optimal portfolio
plt.title('Markowitz Efficient Frontier with Random Portfolios and Optimal Portfolio')
plt.xlabel('Portfolio Volatility (Standard Deviation)')
plt.ylabel('Portfolio Expected Return')
plt.colorbar(label='Expected Return')
plt.legend()
plt.grid(True)
plt.show()

print(f"Optimal Portfolio Expected Return: {optimal_portfolio_return:.4f}")
print(f"Optimal Portfolio Volatility: {optimal_portfolio_volatility*100:.4f}")
# Out:
# Optimal Portfolio Expected Return: 0.0005
# Optimal Portfolio Volatility: 15.6219
